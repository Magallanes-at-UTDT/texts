# %%
import pandas as pd

DTM_URL = (
    "https://github.com/Magallanes-at-UTDT/texts/raw/main/"
    "data/processed/dtm_counts.parquet"
)

dtm = pd.read_parquet(DTM_URL)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf = TfidfTransformer()

dtm_tfidf = tfidf.fit_transform(dtm)

# %%
dtm_tfidf
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 17377 stored elements and shape (6, 8264)>

# %%
dtm_tfidf[:1].toarray()
# Out:
# array([[0.        , 0.        , 0.0020595 , ..., 0.00889274, 0.        ,
#         0.        ]], shape=(1, 8264))

# %%
dtm[:1]
# Out:
#              0270  0e5  1000  1010  1053  10mil  1131  1133  1151  1170  ...  \
# party                                                                    ...
# AhoraNacion     0    0     2     1     0      0     1     1     0     0  ...
#
#              órden  órgano  órganos  últimamente  último  única  únicamente  \
# party
# AhoraNacion      0       1        2            0      19      0           0
#
#              único  útil  ⅓
# party
# AhoraNacion     10     0  0
#
# [1 rows x 8264 columns]

# %%
dtm_tfidf_df = pd.DataFrame(
    dtm_tfidf.toarray(),
    index=dtm.index,
    columns=dtm.columns
)
##
dtm_tfidf_df.iloc[:1]
# Out:
#              0270  0e5     1000      1010  1053  10mil      1131      1133  \
# party
# AhoraNacion   0.0  0.0  0.00206  0.001736   0.0    0.0  0.001736  0.001736
#
#              1151  1170  ...  órden    órgano   órganos  últimamente   último  \
# party                    ...
# AhoraNacion   0.0   0.0  ...    0.0  0.000889  0.002847          0.0  0.01464
#
#              única  únicamente     único  útil    ⅓
# party
# AhoraNacion    0.0         0.0  0.008893   0.0  0.0
#
# [1 rows x 8264 columns]

# %%
dtm[["economía", "salud", "educación"]]
# Out:
#                    economía  salud  educación
# party
# AhoraNacion              63    106         68
# BuenGobierno             25     49         42
# FuerzaPopular            47    120        114
# JuntosPorElPeru          35    125         67
# Obras                     7     21         17
# RenovacionPopular         4     26          7

# %%
dtm_tfidf_df[["economía", "salud", "educación"]]
# Out:
#                    economía     salud  educación
# party
# AhoraNacion        0.048542  0.081673   0.052394
# BuenGobierno       0.029663  0.058139   0.049834
# FuerzaPopular      0.042275  0.107937   0.102540
# JuntosPorElPeru    0.052030  0.185822   0.099601
# Obras              0.040007  0.120022   0.097161
# RenovacionPopular  0.020683  0.134438   0.036195

# %%
dtm_tfidf_df.loc["AhoraNacion"].sort_values(ascending=False).head(20)
# Out:
# nacional       0.278619
# desarrollo     0.212362
# porcentaje     0.193137
# meta           0.160546
# estrategia     0.152126
# sistema        0.150353
# país           0.140159
# perú           0.135062
# estratégico    0.134314
# objetivo       0.132353
# problema       0.123170
# servicios      0.120622
# cuál           0.116730
# acceso         0.110428
# plan           0.100235
# uso            0.095988
# número         0.095988
# sostenible     0.095138
# ahora          0.094151
# nación         0.092157
# Name: AhoraNacion, dtype: float64

# %%
dtm.loc["AhoraNacion"].sort_values(ascending=False).head(20)
# Out:
# nacional       328
# desarrollo     250
# porcentaje     197
# meta           189
# sistema        177
# país           165
# perú           159
# problema       145
# servicios      142
# estratégico    137
# objetivo       135
# estrategia     134
# acceso         130
# plan           118
# número         113
# uso            113
# sostenible     112
# salud          106
# social         104
# gestión        101
# Name: AhoraNacion, dtype: int64

# %% [markdown]
# So if you have six parties:
#
# | Party | Document    |
# | ----- | ----------- |
# | A     | Manifesto A |
# | B     | Manifesto B |
# | C     | Manifesto C |
# | D     | Manifesto D |
# | E     | Manifesto E |
# | F     | Manifesto F |
#
# then, when computing the TF–IDF weights for **Party A**, the algorithm asks:
#
# 1. **TF:** How often does this word appear in Party A's manifesto?
# 2. **IDF:** In how many of the **six manifestos** does this word appear?
#
# A word that appears in **all six parties** receives a much smaller IDF than a word appearing in only one or two parties.
#
#
# > Unlike raw word counts, TF–IDF evaluates each document **relative to the rest of the corpus**. The weight assigned to a word depends not only on how frequently it appears in one party's manifesto, but also on how common that word is across all party manifestos.
